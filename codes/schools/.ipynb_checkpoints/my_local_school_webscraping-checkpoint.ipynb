# %% [markdown]
# This code amalgamates the summary information from the 'mylocalschool.wales' website into one large dictionary for easy access.

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# This is a list of the schools in the local area that we want to focus on.

# %%
local_schools = ['Severn Primary','St. Mary\'s R.C. Primary School','St.Paul\'s C/W Primary School','Grangetown Primary School','St Patrick\'s R C School','Ysgol Gynradd Gymraeg Hamadryad','Ninian Park Primary School','Kitchener Primary School','Radnor Primary School','Lansdowne Primary School','Ysgol Treganna','Ysgol Gymraeg Pwll Coch']

# %% [markdown]
# This function makes a dictionary which associates each school name to the URL of its summary page.

# %%
def make_school_URL_dict_from_list(schools):
    toppage = requests.get("http://mylocalschool.wales.gov.uk/Schools/SchoolSearch?lang=en")
    soup = BeautifulSoup(toppage.content, 'html.parser')
    school_links = soup.select("a[href*=/School]")[2:]
    schools = [list(school.children)[0] for school in school_links]
    school_URLs = ["http://mylocalschool.wales.gov.uk" + school['href'] for school in school_links]
    schoolURL_dict = {}
    for s,school in enumerate(schools):
        schoolURL_dict[school] = school_URLs[s]
    return schoolURL_dict

# %%
schoolURL_dict = make_school_URL_dict_from_list(local_schools)

# %% [markdown]
# This next function takes the URL of a schools summary page and makes a dictionary listing the stats for that school.

# %%
def tofloat(string):
    if string[-1] == '%':
        string = string[:-1]
    elif string == '' or string == '*':
        string = np.nan
    try:
        output = float(string)
    except ValueError:
        output = string
    return output
                
def make_stat_dict(schoolURL):
    school_pages = requests.get(schoolURL)
    school_soup = BeautifulSoup(school_pages.content, 'html.parser')
    summary = school_soup.find_all('div',id=False, class_="summaryBox")
    stat_dict = {}
    for i in range(len(summary)):
        stat = ''.join(char for char in list(summary[i].children)[1].getText() if char.isalnum() or char=='.')
        stat = tofloat(stat)
        stat_name = (''.join(char for char in list(summary[i].children)[3].getText() if char.isalnum() or char==' ')).strip()
        if '%' in list(summary[i].children)[1].getText(): stat_name += "(%)"
        stat_dict[stat_name] = stat
    return stat_dict

# %% [markdown]
# This dictionary links each school to the summary dictionary for that school.

# %%
local_school_dict = {}
for school in local_schools:
    local_school_dict[school] = make_stat_dict(schoolURL_dict[school])

# %% [markdown]
# Now we use pandas to turn this dictionary into a data frame.

# %%
import pandas as pd

# %%
local_school_df = pd.DataFrame.from_dict(local_school_dict, orient='index')

# %%
local_school_df
# Out:
#                                  Number of Pupils 2017  \
# Grangetown Primary School                        404.0
# Kitchener Primary School                         486.0
# Lansdowne Primary School                         486.0
# Ninian Park Primary School                       557.0
# Radnor Primary School                            323.0
# Severn Primary                                   482.0
# St Patrick's R C School                          298.0
# St. Mary's R.C. Primary School                   261.0
# St.Paul's C/W Primary School                     209.0
# Ysgol Gymraeg Pwll Coch                          506.0
# Ysgol Gynradd Gymraeg Hamadryad                   17.0
# Ysgol Treganna                                   623.0
#
#                                  Free school meals FSM  3 year average Primary only(%)  \
# Grangetown Primary School                                                     27.2
# Kitchener Primary School                                                      29.9
# Lansdowne Primary School                                                      29.6
# Ninian Park Primary School                                                    23.7
# Radnor Primary School                                                         19.1
# Severn Primary                                                                24.0
# St Patrick's R C School                                                       23.2
# St. Mary's R.C. Primary School                                                11.1
# St.Paul's C/W Primary School                                                  26.5
# Ysgol Gymraeg Pwll Coch                                                        9.5
# Ysgol Gynradd Gymraeg Hamadryad                                                NaN
# Ysgol Treganna                                                                 4.5
#
#                                  Pupil Teacher Ratio PTR Primary only  \
# Grangetown Primary School                                        19.6
# Kitchener Primary School                                         20.5
# Lansdowne Primary School                                         21.9
# Ninian Park Primary School                                       24.3
# Radnor Primary School                                            18.9
# Severn Primary                                                   20.9
# St Patrick's R C School                                          24.4
# St. Mary's R.C. Primary School                                   21.5
# St.Paul's C/W Primary School                                     23.1
# Ysgol Gymraeg Pwll Coch                                          22.6
# Ysgol Gynradd Gymraeg Hamadryad                                  17.0
# Ysgol Treganna                                                   24.5
#
#                                  Attendance during the year Primary only(%)  \
# Grangetown Primary School                                              94.2
# Kitchener Primary School                                               94.5
# Lansdowne Primary School                                               93.1
# Ninian Park Primary School                                             94.1
# Radnor Primary School                                                  95.6
# Severn Primary                                                         93.9
# St Patrick's R C School                                                94.0
# St. Mary's R.C. Primary School                                         95.7
# St.Paul's C/W Primary School                                           94.7
# Ysgol Gymraeg Pwll Coch                                                95.8
# Ysgol Gynradd Gymraeg Hamadryad                                         NaN
# Ysgol Treganna                                                         97.0
#
#                                  School budget per pupil  \
# Grangetown Primary School                         3623.0
# Kitchener Primary School                          3576.0
# Lansdowne Primary School                          3442.0
# Ninian Park Primary School                        3569.0
# Radnor Primary School                             3862.0
# Severn Primary                                    3947.0
# St Patrick's R C School                           3548.0
# St. Mary's R.C. Primary School                    3388.0
# St.Paul's C/W Primary School                      3774.0
# Ysgol Gymraeg Pwll Coch                           3213.0
# Ysgol Gynradd Gymraeg Hamadryad                  19436.0
# Ysgol Treganna                                    3388.0
#
#                                  Pupils who have reached the expected level  Core subject indicator Key Stage 2(%)  \
# Grangetown Primary School                                                     80.0
# Kitchener Primary School                                                      82.1
# Lansdowne Primary School                                                      85.1
# Ninian Park Primary School                                                    92.5
# Radnor Primary School                                                        100.0
# Severn Primary                                                                87.5
# St Patrick's R C School                                                       91.7
# St. Mary's R.C. Primary School                                                92.3
# St.Paul's C/W Primary School                                                  92.9
# Ysgol Gymraeg Pwll Coch                                                       98.3
# Ysgol Gynradd Gymraeg Hamadryad                                                NaN
# Ysgol Treganna                                                                91.5
#
#                                 Support Category  \
# Grangetown Primary School                 Yellow
# Kitchener Primary School                   Green
# Lansdowne Primary School                   Green
# Ninian Park Primary School                 Green
# Radnor Primary School                      Green
# Severn Primary                             Green
# St Patrick's R C School                   Yellow
# St. Mary's R.C. Primary School            Yellow
# St.Paul's C/W Primary School              Yellow
# Ysgol Gymraeg Pwll Coch                   Yellow
# Ysgol Gynradd Gymraeg Hamadryad           Yellow
# Ysgol Treganna                             Green
#
#                                  Pupils achieving the expected outcome in the Foundation Phase areas of learning(%)  \
# Grangetown Primary School                                                     76.3
# Kitchener Primary School                                                      80.8
# Lansdowne Primary School                                                      92.0
# Ninian Park Primary School                                                    84.0
# Radnor Primary School                                                         92.5
# Severn Primary                                                                85.5
# St Patrick's R C School                                                       95.3
# St. Mary's R.C. Primary School                                               100.0
# St.Paul's C/W Primary School                                                  89.7
# Ysgol Gymraeg Pwll Coch                                                       95.2
# Ysgol Gynradd Gymraeg Hamadryad                                                NaN
# Ysgol Treganna                                                                89.9
#
#                                  Average number of minutes per week allocated for curricular PE Primary only  \
# Grangetown Primary School                                                      NaN
# Kitchener Primary School                                                     105.0
# Lansdowne Primary School                                                      90.0
# Ninian Park Primary School                                                     NaN
# Radnor Primary School                                                        120.0
# Severn Primary                                                                90.0
# St Patrick's R C School                                                        NaN
# St. Mary's R.C. Primary School                                                 NaN
# St.Paul's C/W Primary School                                                 120.0
# Ysgol Gymraeg Pwll Coch                                                        NaN
# Ysgol Gynradd Gymraeg Hamadryad                                                NaN
# Ysgol Treganna                                                                 NaN
#
#                                  of pupils in the school who enjoy PE lessons a lot(%)  \
# Grangetown Primary School                                                      NaN
# Kitchener Primary School                                                      74.0
# Lansdowne Primary School                                                       NaN
# Ninian Park Primary School                                                    61.0
# Radnor Primary School                                                          NaN
# Severn Primary                                                                 NaN
# St Patrick's R C School                                                        NaN
# St. Mary's R.C. Primary School                                                 NaN
# St.Paul's C/W Primary School                                                  74.0
# Ysgol Gymraeg Pwll Coch                                                        NaN
# Ysgol Gynradd Gymraeg Hamadryad                                                NaN
# Ysgol Treganna                                                                 NaN
#
#                                  of pupils in the school who are hooked on sport(%)
# Grangetown Primary School                                                      NaN
# Kitchener Primary School                                                      26.0
# Lansdowne Primary School                                                       NaN
# Ninian Park Primary School                                                    32.0
# Radnor Primary School                                                          NaN
# Severn Primary                                                                 NaN
# St Patrick's R C School                                                        NaN
# St. Mary's R.C. Primary School                                                 NaN
# St.Paul's C/W Primary School                                                  50.0
# Ysgol Gymraeg Pwll Coch                                                        NaN
# Ysgol Gynradd Gymraeg Hamadryad                                                NaN
# Ysgol Treganna                                                                 NaN

# %% [markdown]
# Here we show a summary of the data.

# %%
local_school_df.describe()
# Out:
#        Number of Pupils 2017  \
# count              12.000000
# mean              387.666667
# std               171.661577
# min                17.000000
# 25%               288.750000
# 50%               443.000000
# 75%               491.000000
# max               623.000000
#
#        Free school meals FSM  3 year average Primary only(%)  \
# count                                          11.000000
# mean                                           20.754545
# std                                             8.651285
# min                                             4.500000
# 25%                                            15.100000
# 50%                                            23.700000
# 75%                                            26.850000
# max                                            29.900000
#
#        Pupil Teacher Ratio PTR Primary only  \
# count                             12.000000
# mean                              21.600000
# std                                2.355651
# min                               17.000000
# 25%                               20.275000
# 50%                               21.700000
# 75%                               23.400000
# max                               24.500000
#
#        Attendance during the year Primary only(%)  School budget per pupil  \
# count                                   11.000000                12.000000
# mean                                    94.781818              4897.166667
# std                                      1.121444              4583.328680
# min                                     93.100000              3213.000000
# 25%                                     94.050000              3428.500000
# 50%                                     94.500000              3572.500000
# 75%                                     95.650000              3796.000000
# max                                     97.000000             19436.000000
#
#        Pupils who have reached the expected level  Core subject indicator Key Stage 2(%)  \
# count                                          11.000000
# mean                                           90.354545
# std                                             6.206990
# min                                            80.000000
# 25%                                            86.300000
# 50%                                            91.700000
# 75%                                            92.700000
# max                                           100.000000
#
#        Pupils achieving the expected outcome in the Foundation Phase areas of learning(%)  \
# count                                          11.000000
# mean                                           89.200000
# std                                             6.978682
# min                                            76.300000
# 25%                                            84.750000
# 50%                                            89.900000
# 75%                                            93.850000
# max                                           100.000000
#
#        Average number of minutes per week allocated for curricular PE Primary only  \
# count                                                5.0
# mean                                               105.0
# std                                                 15.0
# min                                                 90.0
# 25%                                                 90.0
# 50%                                                105.0
# 75%                                                120.0
# max                                                120.0
#
#        of pupils in the school who enjoy PE lessons a lot(%)  \
# count                                           3.000000
# mean                                           69.666667
# std                                             7.505553
# min                                            61.000000
# 25%                                            67.500000
# 50%                                            74.000000
# 75%                                            74.000000
# max                                            74.000000
#
#        of pupils in the school who are hooked on sport(%)
# count                                           3.000000
# mean                                           36.000000
# std                                            12.489996
# min                                            26.000000
# 25%                                            29.000000
# 50%                                            32.000000
# 75%                                            41.000000
# max                                            50.000000

# %% [markdown]
# The total number of primary school students in the area is:

# %%
local_num_students = sum(local_school_df['Number of Pupils 2017'])
print(local_num_students)
# Out:
# 4652.0

# %% [markdown]
# Here we use the number of primary school students and the percentage on free school meals to estimate the total number of children in the area who are on free school meals.

# %%
local_fsm_students = sum((pd.to_numeric(local_school_df['Free school meals FSM  3 year average Primary only(%)'])/100 \
                                                  * local_school_df['Number of Pupils 2017']).dropna())
print(local_fsm_students)
# Out:
# 938.0369999999999

# %% [markdown]
# The percentage of primary school students in the area on free school meals is:

# %%
local_fsm_students/local_num_students * 100
# Out:
# 20.164165950128975

# %% [markdown]
# We will now compare the local school statistics to the whole of Cardiff. This next function makes a list of every school in a given district (in this case we are interested in Cardiff), together with their URLs.

# %%
def make_district_school_URLdict(district): 
    toppage = requests.get("http://mylocalschool.wales.gov.uk/Schools/SchoolSearch?lang=en")
    soup = BeautifulSoup(toppage.content, 'html.parser')
    url_ref = [list(soup.find_all("option"))[-1]['value'] for i in range(len(list(soup.select('option')))) \
                                            if list(soup.find_all("option")[i])[0].strip() == district][0]
    school_url_string = "a[href*=/School/" + url_ref + "]"
    school_links = soup.select(school_url_string)
    schools = [list(school.children)[0] for school in school_links]
    school_URLs = ["http://mylocalschool.wales.gov.uk" + school['href'] for school in school_links]
    schoolURL_dict = {}
    for s,school in enumerate(schools):
        schoolURL_dict[school] = school_URLs[s]
    return schoolURL_dict

# %% [markdown]
# This next function searches for schools of a certain type (e.g. primary) in a given district and returns a dictionary of those schools with their URL.

# %%
def make_district_school_URLdict_by_type(district,schools=False):
    school_URLs = make_district_school_URLdict(district)
    schools_URLdict = {}
    for school in school_URLs.keys():
        school_pages = requests.get(school_URLs[school])
        school_soup = BeautifulSoup(school_pages.content, 'html.parser')
        school_type = list(school_soup.select("div[class=schDetailsText]")[1].children)[0].strip()
        if 'Primary' in schools:
            if ('Infants' or 'Juniors') in school_type:
                schools_URLdict[school] = school_URLs[school]
        if 'Secondary' in schools:
            if 'Secondary' in school_type:
                schools_URLdict[school] = school_URLs[school]         
    return schools_URLdict

# %%
primary_school_URLs = make_district_school_URLdict_by_type('Cardiff',schools=['Primary'])

# %% [markdown]
# We then make a dictionary linking each primary school in Cardiff to its summary information.

# %%
cardiff_primary_school_dict = {}
for school in primary_school_URLs.keys():
    cardiff_primary_school_dict[school] = make_stat_dict(primary_school_URLs[school])

# %% [markdown]
# We then turn this dictionary into a dataframe.

# %%
cardiff_primary_school_df = pd.DataFrame.from_dict(cardiff_primary_school_dict, orient='index')

# %%
cardiff_primary_school_df
# Out:
#                                      Number of Pupils 2017  \
# Adamsdown Primary                                    371.0
# Albany Primary School                                457.0
# All Saints C/W Primary                               194.0
# Allensbank Primary School                            283.0
# Baden Powell Primary School                          417.0
# Birchgrove Primary School                            413.0
# Bishop Childs C/W Primary                            212.0
# Bryn Celyn Primary School                            194.0
# Bryn Deri Primary                                    251.0
# Bryn Hafod Primary School                            368.0
# Christ The King Primary School                       228.0
# Coed Glas C P School                                 592.0
# Coryton Primary                                      237.0
# Creigiau Primary School                              422.0
# Danescourt Primary                                   419.0
# Fairwater Primary School                             234.0
# Gabalfa Primary                                      295.0
# Gladstone Primary School                             236.0
# Glan Yr Afon Primary School                          200.0
# Glyncoed Primary                                     415.0
# Grangetown Primary School                            404.0
# Greenway Primary School                              240.0
# Hawthorn Primary                                     253.0
# Herbert Thompson Primary                             524.0
# Holy Family R.C. Primary                             126.0
# Howardian Primary School                             157.0
# Hywel Dda Primary School                             468.0
# Kitchener Primary School                             486.0
# Lakeside Primary School                              525.0
# Lansdowne Primary School                             486.0
# ...                                                    ...
# St. Mary's R.C. Primary School                       261.0
# St. Mellons Church In Wales Primary                  116.0
# St. Peter's Primary School                           556.0
# St.Paul's C/W Primary School                         209.0
# Stacey Primary School                                217.0
# Thornhill Primary School                             469.0
# Ton-yr-Ywen Primary School                           516.0
# Tongwynlais Primary School                           237.0
# Tredegarville C/W Primary                            246.0
# Trelai Primary School                                427.0
# Trowbridge Primary                                   217.0
# Whitchurch Primary                                   705.0
# Willowbrook Primary School                           441.0
# Windsor Clive Primary                                432.0
# Y G G Gwaelod Y Garth                                275.0
# Ysgol Bro Eirwg                                      459.0
# Ysgol Glan Ceubal                                    133.0
# Ysgol Glan Morfa                                     212.0
# Ysgol Gymraeg Coed Y Gof                             341.0
# Ysgol Gymraeg Melin Gruffydd                         476.0
# Ysgol Gymraeg Nant Caerau                            242.0
# Ysgol Gymraeg Pwll Coch                              506.0
# Ysgol Gynradd Gymraeg Hamadryad                       17.0
# Ysgol Gynradd Gymraeg Pen-Y-Groes                    113.0
# Ysgol Mynydd Bychan                                  271.0
# Ysgol Pen Y Pil                                      210.0
# Ysgol Pencae                                         208.0
# Ysgol Treganna                                       623.0
# Ysgol Y Berllan Deg                                  455.0
# Ysgol Y Wern                                         571.0
#
#                                      Free school meals FSM  3 year average Primary only(%)  \
# Adamsdown Primary                                                                 44.6
# Albany Primary School                                                             24.9
# All Saints C/W Primary                                                            19.2
# Allensbank Primary School                                                         24.6
# Baden Powell Primary School                                                       35.2
# Birchgrove Primary School                                                          8.5
# Bishop Childs C/W Primary                                                         12.2
# Bryn Celyn Primary School                                                         58.2
# Bryn Deri Primary                                                                  4.3
# Bryn Hafod Primary School                                                         37.5
# Christ The King Primary School                                                     4.9
# Coed Glas C P School                                                              25.0
# Coryton Primary                                                                   17.9
# Creigiau Primary School                                                            3.3
# Danescourt Primary                                                                 9.7
# Fairwater Primary School                                                          33.9
# Gabalfa Primary                                                                   45.3
# Gladstone Primary School                                                          19.0
# Glan Yr Afon Primary School                                                       46.0
# Glyncoed Primary                                                                  23.4
# Grangetown Primary School                                                         27.2
# Greenway Primary School                                                           60.3
# Hawthorn Primary                                                                  23.7
# Herbert Thompson Primary                                                          50.2
# Holy Family R.C. Primary                                                          26.3
# Howardian Primary School                                                          16.4
# Hywel Dda Primary School                                                          49.2
# Kitchener Primary School                                                          29.9
# Lakeside Primary School                                                            7.3
# Lansdowne Primary School                                                          29.6
# ...                                                                                ...
# St. Mary's R.C. Primary School                                                    11.1
# St. Mellons Church In Wales Primary                                               12.0
# St. Peter's Primary School                                                        13.2
# St.Paul's C/W Primary School                                                      26.5
# Stacey Primary School                                                             33.6
# Thornhill Primary School                                                          11.1
# Ton-yr-Ywen Primary School                                                         7.2
# Tongwynlais Primary School                                                        16.0
# Tredegarville C/W Primary                                                         35.8
# Trelai Primary School                                                             51.4
# Trowbridge Primary                                                                53.3
# Whitchurch Primary                                                                11.5
# Willowbrook Primary School                                                        30.3
# Windsor Clive Primary                                                             55.2
# Y G G Gwaelod Y Garth                                                              4.1
# Ysgol Bro Eirwg                                                                   16.7
# Ysgol Glan Ceubal                                                                 30.1
# Ysgol Glan Morfa                                                                  28.4
# Ysgol Gymraeg Coed Y Gof                                                          24.1
# Ysgol Gymraeg Melin Gruffydd                                                       5.5
# Ysgol Gymraeg Nant Caerau                                                         26.0
# Ysgol Gymraeg Pwll Coch                                                            9.5
# Ysgol Gynradd Gymraeg Hamadryad                                                    NaN
# Ysgol Gynradd Gymraeg Pen-Y-Groes                                                 16.2
# Ysgol Mynydd Bychan                                                                7.1
# Ysgol Pen Y Pil                                                                   23.8
# Ysgol Pencae                                                                       2.6
# Ysgol Treganna                                                                     4.5
# Ysgol Y Berllan Deg                                                                5.0
# Ysgol Y Wern                                                                       5.6
#
#                                      Pupil Teacher Ratio PTR Primary only  \
# Adamsdown Primary                                                    19.2
# Albany Primary School                                                24.1
# All Saints C/W Primary                                               22.9
# Allensbank Primary School                                            19.1
# Baden Powell Primary School                                          20.8
# Birchgrove Primary School                                            25.9
# Bishop Childs C/W Primary                                            25.9
# Bryn Celyn Primary School                                            20.8
# Bryn Deri Primary                                                    20.4
# Bryn Hafod Primary School                                            21.4
# Christ The King Primary School                                       21.4
# Coed Glas C P School                                                 18.3
# Coryton Primary                                                      25.2
# Creigiau Primary School                                              22.1
# Danescourt Primary                                                   23.6
# Fairwater Primary School                                             21.9
# Gabalfa Primary                                                      19.1
# Gladstone Primary School                                             20.6
# Glan Yr Afon Primary School                                          18.4
# Glyncoed Primary                                                     18.7
# Grangetown Primary School                                            19.6
# Greenway Primary School                                              22.0
# Hawthorn Primary                                                     26.8
# Herbert Thompson Primary                                             23.1
# Holy Family R.C. Primary                                             18.8
# Howardian Primary School                                             25.8
# Hywel Dda Primary School                                             24.3
# Kitchener Primary School                                             20.5
# Lakeside Primary School                                              26.2
# Lansdowne Primary School                                             21.9
# ...                                                                   ...
# St. Mary's R.C. Primary School                                       21.5
# St. Mellons Church In Wales Primary                                  20.7
# St. Peter's Primary School                                           21.8
# St.Paul's C/W Primary School                                         23.1
# Stacey Primary School                                                17.4
# Thornhill Primary School                                             24.2
# Ton-yr-Ywen Primary School                                           22.2
# Tongwynlais Primary School                                           20.3
# Tredegarville C/W Primary                                            20.8
# Trelai Primary School                                                19.8
# Trowbridge Primary                                                   19.6
# Whitchurch Primary                                                   27.7
# Willowbrook Primary School                                           21.3
# Windsor Clive Primary                                                21.5
# Y G G Gwaelod Y Garth                                                21.3
# Ysgol Bro Eirwg                                                      20.8
# Ysgol Glan Ceubal                                                    15.5
# Ysgol Glan Morfa                                                     19.5
# Ysgol Gymraeg Coed Y Gof                                             20.1
# Ysgol Gymraeg Melin Gruffydd                                         25.4
# Ysgol Gymraeg Nant Caerau                                            21.6
# Ysgol Gymraeg Pwll Coch                                              22.6
# Ysgol Gynradd Gymraeg Hamadryad                                      17.0
# Ysgol Gynradd Gymraeg Pen-Y-Groes                                    14.7
# Ysgol Mynydd Bychan                                                  22.5
# Ysgol Pen Y Pil                                                      14.6
# Ysgol Pencae                                                         23.5
# Ysgol Treganna                                                       24.5
# Ysgol Y Berllan Deg                                                  22.9
# Ysgol Y Wern                                                         21.0
#
#                                      Attendance during the year Primary only(%)  \
# Adamsdown Primary                                                          93.3
# Albany Primary School                                                      94.3
# All Saints C/W Primary                                                     94.6
# Allensbank Primary School                                                  92.6
# Baden Powell Primary School                                                93.8
# Birchgrove Primary School                                                  96.2
# Bishop Childs C/W Primary                                                  95.4
# Bryn Celyn Primary School                                                  95.0
# Bryn Deri Primary                                                          96.5
# Bryn Hafod Primary School                                                  94.8
# Christ The King Primary School                                             96.5
# Coed Glas C P School                                                       94.5
# Coryton Primary                                                            95.2
# Creigiau Primary School                                                    96.5
# Danescourt Primary                                                         94.9
# Fairwater Primary School                                                   94.2
# Gabalfa Primary                                                            94.1
# Gladstone Primary School                                                   94.3
# Glan Yr Afon Primary School                                                94.4
# Glyncoed Primary                                                           95.0
# Grangetown Primary School                                                  94.2
# Greenway Primary School                                                    93.9
# Hawthorn Primary                                                           95.5
# Herbert Thompson Primary                                                   93.3
# Holy Family R.C. Primary                                                   96.0
# Howardian Primary School                                                   94.7
# Hywel Dda Primary School                                                   94.0
# Kitchener Primary School                                                   94.5
# Lakeside Primary School                                                    95.7
# Lansdowne Primary School                                                   93.1
# ...                                                                         ...
# St. Mary's R.C. Primary School                                             95.7
# St. Mellons Church In Wales Primary                                        95.3
# St. Peter's Primary School                                                 95.5
# St.Paul's C/W Primary School                                               94.7
# Stacey Primary School                                                      93.8
# Thornhill Primary School                                                   94.9
# Ton-yr-Ywen Primary School                                                 96.0
# Tongwynlais Primary School                                                 95.3
# Tredegarville C/W Primary                                                  94.2
# Trelai Primary School                                                      92.5
# Trowbridge Primary                                                         92.3
# Whitchurch Primary                                                         96.7
# Willowbrook Primary School                                                 95.4
# Windsor Clive Primary                                                      93.0
# Y G G Gwaelod Y Garth                                                      96.6
# Ysgol Bro Eirwg                                                            94.7
# Ysgol Glan Ceubal                                                          94.6
# Ysgol Glan Morfa                                                           94.7
# Ysgol Gymraeg Coed Y Gof                                                   93.9
# Ysgol Gymraeg Melin Gruffydd                                               96.9
# Ysgol Gymraeg Nant Caerau                                                  94.9
# Ysgol Gymraeg Pwll Coch                                                    95.8
# Ysgol Gynradd Gymraeg Hamadryad                                             NaN
# Ysgol Gynradd Gymraeg Pen-Y-Groes                                          94.2
# Ysgol Mynydd Bychan                                                        96.7
# Ysgol Pen Y Pil                                                            95.0
# Ysgol Pencae                                                               97.0
# Ysgol Treganna                                                             97.0
# Ysgol Y Berllan Deg                                                        96.5
# Ysgol Y Wern                                                               96.9
#
#                                      School budget per pupil  \
# Adamsdown Primary                                     3757.0
# Albany Primary School                                 3422.0
# All Saints C/W Primary                                3565.0
# Allensbank Primary School                             4541.0
# Baden Powell Primary School                           3757.0
# Birchgrove Primary School                             3192.0
# Bishop Childs C/W Primary                             3490.0
# Bryn Celyn Primary School                             4357.0
# Bryn Deri Primary                                     3935.0
# Bryn Hafod Primary School                             4270.0
# Christ The King Primary School                        3534.0
# Coed Glas C P School                                  4175.0
# Coryton Primary                                       3959.0
# Creigiau Primary School                               3504.0
# Danescourt Primary                                    3512.0
# Fairwater Primary School                              4266.0
# Gabalfa Primary                                       4194.0
# Gladstone Primary School                              3851.0
# Glan Yr Afon Primary School                           5262.0
# Glyncoed Primary                                      3448.0
# Grangetown Primary School                             3623.0
# Greenway Primary School                               4156.0
# Hawthorn Primary                                      4062.0
# Herbert Thompson Primary                              3608.0
# Holy Family R.C. Primary                              5190.0
# Howardian Primary School                              5075.0
# Hywel Dda Primary School                              3778.0
# Kitchener Primary School                              3576.0
# Lakeside Primary School                               3341.0
# Lansdowne Primary School                              3442.0
# ...                                                      ...
# St. Mary's R.C. Primary School                        3388.0
# St. Mellons Church In Wales Primary                   4771.0
# St. Peter's Primary School                            3095.0
# St.Paul's C/W Primary School                          3774.0
# Stacey Primary School                                 4404.0
# Thornhill Primary School                              3303.0
# Ton-yr-Ywen Primary School                            3497.0
# Tongwynlais Primary School                            3742.0
# Tredegarville C/W Primary                             3901.0
# Trelai Primary School                                 4095.0
# Trowbridge Primary                                    4063.0
# Whitchurch Primary                                    3295.0
# Willowbrook Primary School                            3476.0
# Windsor Clive Primary                                 4047.0
# Y G G Gwaelod Y Garth                                 3855.0
# Ysgol Bro Eirwg                                       3389.0
# Ysgol Glan Ceubal                                     4879.0
# Ysgol Glan Morfa                                      4378.0
# Ysgol Gymraeg Coed Y Gof                              3784.0
# Ysgol Gymraeg Melin Gruffydd                          3311.0
# Ysgol Gymraeg Nant Caerau                             3983.0
# Ysgol Gymraeg Pwll Coch                               3213.0
# Ysgol Gynradd Gymraeg Hamadryad                      19436.0
# Ysgol Gynradd Gymraeg Pen-Y-Groes                     5730.0
# Ysgol Mynydd Bychan                                   3537.0
# Ysgol Pen Y Pil                                       3935.0
# Ysgol Pencae                                          4218.0
# Ysgol Treganna                                        3388.0
# Ysgol Y Berllan Deg                                   3290.0
# Ysgol Y Wern                                          3298.0
#
#                                      Pupils who have reached the expected level  Core subject indicator Key Stage 2(%)  \
# Adamsdown Primary                                                                 78.3
# Albany Primary School                                                             77.8
# All Saints C/W Primary                                                           100.0
# Allensbank Primary School                                                         76.2
# Baden Powell Primary School                                                       87.5
# Birchgrove Primary School                                                         98.2
# Bishop Childs C/W Primary                                                         96.8
# Bryn Celyn Primary School                                                         85.7
# Bryn Deri Primary                                                                100.0
# Bryn Hafod Primary School                                                         95.5
# Christ The King Primary School                                                    97.7
# Coed Glas C P School                                                              91.4
# Coryton Primary                                                                   90.0
# Creigiau Primary School                                                           96.4
# Danescourt Primary                                                                92.5
# Fairwater Primary School                                                          81.8
# Gabalfa Primary                                                                   87.5
# Gladstone Primary School                                                          92.0
# Glan Yr Afon Primary School                                                       73.9
# Glyncoed Primary                                                                  98.2
# Grangetown Primary School                                                         80.0
# Greenway Primary School                                                           88.9
# Hawthorn Primary                                                                  83.3
# Herbert Thompson Primary                                                          84.5
# Holy Family R.C. Primary                                                          76.9
# Howardian Primary School                                                           NaN
# Hywel Dda Primary School                                                          88.7
# Kitchener Primary School                                                          82.1
# Lakeside Primary School                                                           96.6
# Lansdowne Primary School                                                          85.1
# ...                                                                                ...
# St. Mary's R.C. Primary School                                                    92.3
# St. Mellons Church In Wales Primary                                               94.1
# St. Peter's Primary School                                                        90.9
# St.Paul's C/W Primary School                                                      92.9
# Stacey Primary School                                                             87.0
# Thornhill Primary School                                                          95.0
# Ton-yr-Ywen Primary School                                                        95.0
# Tongwynlais Primary School                                                        84.0
# Tredegarville C/W Primary                                                         84.6
# Trelai Primary School                                                             70.4
# Trowbridge Primary                                                                89.3
# Whitchurch Primary                                                                97.8
# Willowbrook Primary School                                                        97.4
# Windsor Clive Primary                                                             82.5
# Y G G Gwaelod Y Garth                                                             92.9
# Ysgol Bro Eirwg                                                                   88.2
# Ysgol Glan Ceubal                                                                 85.7
# Ysgol Glan Morfa                                                                  90.0
# Ysgol Gymraeg Coed Y Gof                                                          82.2
# Ysgol Gymraeg Melin Gruffydd                                                      93.1
# Ysgol Gymraeg Nant Caerau                                                         86.7
# Ysgol Gymraeg Pwll Coch                                                           98.3
# Ysgol Gynradd Gymraeg Hamadryad                                                    NaN
# Ysgol Gynradd Gymraeg Pen-Y-Groes                                                100.0
# Ysgol Mynydd Bychan                                                              100.0
# Ysgol Pen Y Pil                                                                  100.0
# Ysgol Pencae                                                                     100.0
# Ysgol Treganna                                                                    91.5
# Ysgol Y Berllan Deg                                                               94.5
# Ysgol Y Wern                                                                      93.0
#
#                                     Support Category  \
# Adamsdown Primary                             Yellow
# Albany Primary School                         Yellow
# All Saints C/W Primary                        Yellow
# Allensbank Primary School                      Amber
# Baden Powell Primary School                    Amber
# Birchgrove Primary School                      Green
# Bishop Childs C/W Primary                      Green
# Bryn Celyn Primary School                     Yellow
# Bryn Deri Primary                              Green
# Bryn Hafod Primary School                      Green
# Christ The King Primary School                 Green
# Coed Glas C P School                           Green
# Coryton Primary                               Yellow
# Creigiau Primary School                        Green
# Danescourt Primary                             Green
# Fairwater Primary School                      Yellow
# Gabalfa Primary                                Green
# Gladstone Primary School                      Yellow
# Glan Yr Afon Primary School                    Amber
# Glyncoed Primary                               Green
# Grangetown Primary School                     Yellow
# Greenway Primary School                        Green
# Hawthorn Primary                              Yellow
# Herbert Thompson Primary                       Green
# Holy Family R.C. Primary                      Yellow
# Howardian Primary School                      Yellow
# Hywel Dda Primary School                       Green
# Kitchener Primary School                       Green
# Lakeside Primary School                        Green
# Lansdowne Primary School                       Green
# ...                                              ...
# St. Mary's R.C. Primary School                Yellow
# St. Mellons Church In Wales Primary            Green
# St. Peter's Primary School                    Yellow
# St.Paul's C/W Primary School                  Yellow
# Stacey Primary School                          Green
# Thornhill Primary School                       Green
# Ton-yr-Ywen Primary School                    Yellow
# Tongwynlais Primary School                     Green
# Tredegarville C/W Primary                      Green
# Trelai Primary School                          Amber
# Trowbridge Primary                             Amber
# Whitchurch Primary                             Green
# Willowbrook Primary School                     Green
# Windsor Clive Primary                          Green
# Y G G Gwaelod Y Garth                          Green
# Ysgol Bro Eirwg                               Yellow
# Ysgol Glan Ceubal                             Yellow
# Ysgol Glan Morfa                              Yellow
# Ysgol Gymraeg Coed Y Gof                      Yellow
# Ysgol Gymraeg Melin Gruffydd                   Green
# Ysgol Gymraeg Nant Caerau                     Yellow
# Ysgol Gymraeg Pwll Coch                       Yellow
# Ysgol Gynradd Gymraeg Hamadryad               Yellow
# Ysgol Gynradd Gymraeg Pen-Y-Groes             Yellow
# Ysgol Mynydd Bychan                            Green
# Ysgol Pen Y Pil                               Yellow
# Ysgol Pencae                                   Green
# Ysgol Treganna                                 Green
# Ysgol Y Berllan Deg                            Green
# Ysgol Y Wern                                   Green
#
#                                      Pupils achieving the expected outcome in the Foundation Phase areas of learning(%)  \
# Adamsdown Primary                                                                 69.2
# Albany Primary School                                                             80.0
# All Saints C/W Primary                                                            93.3
# Allensbank Primary School                                                         86.2
# Baden Powell Primary School                                                       84.6
# Birchgrove Primary School                                                         94.8
# Bishop Childs C/W Primary                                                         93.5
# Bryn Celyn Primary School                                                         87.5
# Bryn Deri Primary                                                                 96.7
# Bryn Hafod Primary School                                                         84.4
# Christ The King Primary School                                                    93.3
# Coed Glas C P School                                                              93.4
# Coryton Primary                                                                   93.3
# Creigiau Primary School                                                           98.0
# Danescourt Primary                                                                96.6
# Fairwater Primary School                                                          84.2
# Gabalfa Primary                                                                   86.7
# Gladstone Primary School                                                          90.5
# Glan Yr Afon Primary School                                                       88.2
# Glyncoed Primary                                                                  96.1
# Grangetown Primary School                                                         76.3
# Greenway Primary School                                                           93.1
# Hawthorn Primary                                                                  92.9
# Herbert Thompson Primary                                                          76.5
# Holy Family R.C. Primary                                                          91.7
# Howardian Primary School                                                           NaN
# Hywel Dda Primary School                                                          86.2
# Kitchener Primary School                                                          80.8
# Lakeside Primary School                                                           94.9
# Lansdowne Primary School                                                          92.0
# ...                                                                                ...
# St. Mary's R.C. Primary School                                                   100.0
# St. Mellons Church In Wales Primary                                              100.0
# St. Peter's Primary School                                                        93.2
# St.Paul's C/W Primary School                                                      89.7
# Stacey Primary School                                                             87.5
# Thornhill Primary School                                                          89.8
# Ton-yr-Ywen Primary School                                                        98.3
# Tongwynlais Primary School                                                        82.1
# Tredegarville C/W Primary                                                         76.7
# Trelai Primary School                                                             75.9
# Trowbridge Primary                                                                91.7
# Whitchurch Primary                                                                96.7
# Willowbrook Primary School                                                        93.1
# Windsor Clive Primary                                                             87.7
# Y G G Gwaelod Y Garth                                                            100.0
# Ysgol Bro Eirwg                                                                   93.0
# Ysgol Glan Ceubal                                                                 72.7
# Ysgol Glan Morfa                                                                  96.3
# Ysgol Gymraeg Coed Y Gof                                                          84.6
# Ysgol Gymraeg Melin Gruffydd                                                     100.0
# Ysgol Gymraeg Nant Caerau                                                         92.6
# Ysgol Gymraeg Pwll Coch                                                           95.2
# Ysgol Gynradd Gymraeg Hamadryad                                                    NaN
# Ysgol Gynradd Gymraeg Pen-Y-Groes                                                 81.8
# Ysgol Mynydd Bychan                                                               93.3
# Ysgol Pen Y Pil                                                                   61.5
# Ysgol Pencae                                                                      80.0
# Ysgol Treganna                                                                    89.9
# Ysgol Y Berllan Deg                                                               90.0
# Ysgol Y Wern                                                                      88.0
#
#                                      of pupils in the school who enjoy PE lessons a lot(%)  \
# Adamsdown Primary                                                                 75.0
# Albany Primary School                                                              NaN
# All Saints C/W Primary                                                             NaN
# Allensbank Primary School                                                          NaN
# Baden Powell Primary School                                                        NaN
# Birchgrove Primary School                                                         74.0
# Bishop Childs C/W Primary                                                          NaN
# Bryn Celyn Primary School                                                          NaN
# Bryn Deri Primary                                                                  NaN
# Bryn Hafod Primary School                                                          NaN
# Christ The King Primary School                                                     NaN
# Coed Glas C P School                                                               NaN
# Coryton Primary                                                                    NaN
# Creigiau Primary School                                                            NaN
# Danescourt Primary                                                                 NaN
# Fairwater Primary School                                                           NaN
# Gabalfa Primary                                                                    NaN
# Gladstone Primary School                                                           NaN
# Glan Yr Afon Primary School                                                        NaN
# Glyncoed Primary                                                                  73.0
# Grangetown Primary School                                                          NaN
# Greenway Primary School                                                           81.0
# Hawthorn Primary                                                                   NaN
# Herbert Thompson Primary                                                          83.0
# Holy Family R.C. Primary                                                           NaN
# Howardian Primary School                                                           NaN
# Hywel Dda Primary School                                                          85.0
# Kitchener Primary School                                                          74.0
# Lakeside Primary School                                                            NaN
# Lansdowne Primary School                                                           NaN
# ...                                                                                ...
# St. Mary's R.C. Primary School                                                     NaN
# St. Mellons Church In Wales Primary                                               86.0
# St. Peter's Primary School                                                         NaN
# St.Paul's C/W Primary School                                                      74.0
# Stacey Primary School                                                              NaN
# Thornhill Primary School                                                           NaN
# Ton-yr-Ywen Primary School                                                         NaN
# Tongwynlais Primary School                                                         NaN
# Tredegarville C/W Primary                                                          NaN
# Trelai Primary School                                                              NaN
# Trowbridge Primary                                                                 NaN
# Whitchurch Primary                                                                 NaN
# Willowbrook Primary School                                                        75.0
# Windsor Clive Primary                                                              NaN
# Y G G Gwaelod Y Garth                                                              NaN
# Ysgol Bro Eirwg                                                                   71.0
# Ysgol Glan Ceubal                                                                  NaN
# Ysgol Glan Morfa                                                                   NaN
# Ysgol Gymraeg Coed Y Gof                                                           NaN
# Ysgol Gymraeg Melin Gruffydd                                                      69.0
# Ysgol Gymraeg Nant Caerau                                                          NaN
# Ysgol Gymraeg Pwll Coch                                                            NaN
# Ysgol Gynradd Gymraeg Hamadryad                                                    NaN
# Ysgol Gynradd Gymraeg Pen-Y-Groes                                                  NaN
# Ysgol Mynydd Bychan                                                                NaN
# Ysgol Pen Y Pil                                                                    NaN
# Ysgol Pencae                                                                       NaN
# Ysgol Treganna                                                                     NaN
# Ysgol Y Berllan Deg                                                                NaN
# Ysgol Y Wern                                                                      75.0
#
#                                      of pupils in the school who are hooked on sport(%)  \
# Adamsdown Primary                                                                 56.0
# Albany Primary School                                                              NaN
# All Saints C/W Primary                                                             NaN
# Allensbank Primary School                                                          NaN
# Baden Powell Primary School                                                        NaN
# Birchgrove Primary School                                                         51.0
# Bishop Childs C/W Primary                                                          NaN
# Bryn Celyn Primary School                                                          NaN
# Bryn Deri Primary                                                                  NaN
# Bryn Hafod Primary School                                                          NaN
# Christ The King Primary School                                                     NaN
# Coed Glas C P School                                                               NaN
# Coryton Primary                                                                    NaN
# Creigiau Primary School                                                            NaN
# Danescourt Primary                                                                 NaN
# Fairwater Primary School                                                           NaN
# Gabalfa Primary                                                                    NaN
# Gladstone Primary School                                                           NaN
# Glan Yr Afon Primary School                                                        NaN
# Glyncoed Primary                                                                  35.0
# Grangetown Primary School                                                          NaN
# Greenway Primary School                                                           31.0
# Hawthorn Primary                                                                   NaN
# Herbert Thompson Primary                                                          42.0
# Holy Family R.C. Primary                                                           NaN
# Howardian Primary School                                                           NaN
# Hywel Dda Primary School                                                          58.0
# Kitchener Primary School                                                          26.0
# Lakeside Primary School                                                            NaN
# Lansdowne Primary School                                                           NaN
# ...                                                                                ...
# St. Mary's R.C. Primary School                                                     NaN
# St. Mellons Church In Wales Primary                                               67.0
# St. Peter's Primary School                                                         NaN
# St.Paul's C/W Primary School                                                      50.0
# Stacey Primary School                                                              NaN
# Thornhill Primary School                                                           NaN
# Ton-yr-Ywen Primary School                                                         NaN
# Tongwynlais Primary School                                                         NaN
# Tredegarville C/W Primary                                                          NaN
# Trelai Primary School                                                              NaN
# Trowbridge Primary                                                                 NaN
# Whitchurch Primary                                                                 NaN
# Willowbrook Primary School                                                        35.0
# Windsor Clive Primary                                                              NaN
# Y G G Gwaelod Y Garth                                                              NaN
# Ysgol Bro Eirwg                                                                   56.0
# Ysgol Glan Ceubal                                                                  NaN
# Ysgol Glan Morfa                                                                   NaN
# Ysgol Gymraeg Coed Y Gof                                                           NaN
# Ysgol Gymraeg Melin Gruffydd                                                      66.0
# Ysgol Gymraeg Nant Caerau                                                          NaN
# Ysgol Gymraeg Pwll Coch                                                            NaN
# Ysgol Gynradd Gymraeg Hamadryad                                                    NaN
# Ysgol Gynradd Gymraeg Pen-Y-Groes                                                  NaN
# Ysgol Mynydd Bychan                                                                NaN
# Ysgol Pen Y Pil                                                                    NaN
# Ysgol Pencae                                                                       NaN
# Ysgol Treganna                                                                     NaN
# Ysgol Y Berllan Deg                                                                NaN
# Ysgol Y Wern                                                                      52.0
#
#                                      Average number of minutes per week allocated for curricular PE Primary only
# Adamsdown Primary                                                                 60.0
# Albany Primary School                                                            120.0
# All Saints C/W Primary                                                             NaN
# Allensbank Primary School                                                          NaN
# Baden Powell Primary School                                                        NaN
# Birchgrove Primary School                                                        100.0
# Bishop Childs C/W Primary                                                          NaN
# Bryn Celyn Primary School                                                          NaN
# Bryn Deri Primary                                                                  NaN
# Bryn Hafod Primary School                                                         60.0
# Christ The King Primary School                                                    60.0
# Coed Glas C P School                                                               NaN
# Coryton Primary                                                                  120.0
# Creigiau Primary School                                                          100.0
# Danescourt Primary                                                                 2.0
# Fairwater Primary School                                                           NaN
# Gabalfa Primary                                                                    NaN
# Gladstone Primary School                                                         110.0
# Glan Yr Afon Primary School                                                        NaN
# Glyncoed Primary                                                                 120.0
# Grangetown Primary School                                                          NaN
# Greenway Primary School                                                          115.0
# Hawthorn Primary                                                                  96.0
# Herbert Thompson Primary                                                          90.0
# Holy Family R.C. Primary                                                           NaN
# Howardian Primary School                                                           NaN
# Hywel Dda Primary School                                                           NaN
# Kitchener Primary School                                                         105.0
# Lakeside Primary School                                                          120.0
# Lansdowne Primary School                                                          90.0
# ...                                                                                ...
# St. Mary's R.C. Primary School                                                     NaN
# St. Mellons Church In Wales Primary                                               90.0
# St. Peter's Primary School                                                         NaN
# St.Paul's C/W Primary School                                                     120.0
# Stacey Primary School                                                              NaN
# Thornhill Primary School                                                           NaN
# Ton-yr-Ywen Primary School                                                       120.0
# Tongwynlais Primary School                                                         NaN
# Tredegarville C/W Primary                                                          NaN
# Trelai Primary School                                                              NaN
# Trowbridge Primary                                                                 NaN
# Whitchurch Primary                                                                 NaN
# Willowbrook Primary School                                                       120.0
# Windsor Clive Primary                                                            120.0
# Y G G Gwaelod Y Garth                                                             60.0
# Ysgol Bro Eirwg                                                                  120.0
# Ysgol Glan Ceubal                                                                  NaN
# Ysgol Glan Morfa                                                                 120.0
# Ysgol Gymraeg Coed Y Gof                                                          90.0
# Ysgol Gymraeg Melin Gruffydd                                                       NaN
# Ysgol Gymraeg Nant Caerau                                                          NaN
# Ysgol Gymraeg Pwll Coch                                                            NaN
# Ysgol Gynradd Gymraeg Hamadryad                                                    NaN
# Ysgol Gynradd Gymraeg Pen-Y-Groes                                                  NaN
# Ysgol Mynydd Bychan                                                              120.0
# Ysgol Pen Y Pil                                                                    NaN
# Ysgol Pencae                                                                     120.0
# Ysgol Treganna                                                                     NaN
# Ysgol Y Berllan Deg                                                                NaN
# Ysgol Y Wern                                                                     120.0
#
# [98 rows x 11 columns]

# %% [markdown]
# We can now look at the summary information for this data.

# %%
cardiff_primary_school_df.describe()
# Out:
#        Number of Pupils 2017  \
# count              98.000000
# mean              341.520408
# std               144.794716
# min                17.000000
# 25%               229.250000
# 50%               326.000000
# 75%               457.000000
# max               708.000000
#
#        Free school meals FSM  3 year average Primary only(%)  \
# count                                          97.000000
# mean                                           23.885567
# std                                            15.547923
# min                                             1.900000
# 25%                                             9.900000
# 50%                                            23.700000
# 75%                                            34.300000
# max                                            60.300000
#
#        Pupil Teacher Ratio PTR Primary only  \
# count                             98.000000
# mean                              21.522449
# std                                2.941510
# min                               14.200000
# 25%                               19.925000
# 50%                               21.400000
# 75%                               23.325000
# max                               28.600000
#
#        Attendance during the year Primary only(%)  School budget per pupil  \
# count                                   97.000000                98.000000
# mean                                    94.945361              4070.428571
# std                                      1.175622              1673.617133
# min                                     92.100000              3095.000000
# 25%                                     94.100000              3491.750000
# 50%                                     94.900000              3812.000000
# 75%                                     95.800000              4200.750000
# max                                     97.100000             19436.000000
#
#        Pupils who have reached the expected level  Core subject indicator Key Stage 2(%)  \
# count                                          95.000000
# mean                                           89.951579
# std                                             7.333439
# min                                            69.200000
# 25%                                            85.400000
# 50%                                            90.500000
# 75%                                            96.400000
# max                                           100.000000
#
#        Pupils achieving the expected outcome in the Foundation Phase areas of learning(%)  \
# count                                          95.000000
# mean                                           88.174737
# std                                             9.180587
# min                                            44.400000
# 25%                                            83.650000
# 50%                                            90.500000
# 75%                                            94.850000
# max                                           100.000000
#
#        of pupils in the school who enjoy PE lessons a lot(%)  \
# count                                          26.000000
# mean                                           75.038462
# std                                             8.224261
# min                                            59.000000
# 25%                                            71.000000
# 50%                                            74.000000
# 75%                                            81.000000
# max                                            93.000000
#
#        of pupils in the school who are hooked on sport(%)  \
# count                                          26.000000
# mean                                           47.384615
# std                                            12.592305
# min                                            26.000000
# 25%                                            36.250000
# 50%                                            49.500000
# 75%                                            56.000000
# max                                            68.000000
#
#        Average number of minutes per week allocated for curricular PE Primary only
# count                                          51.000000
# mean                                           96.137255
# std                                            30.408564
# min                                             2.000000
# 25%                                            90.000000
# 50%                                           105.000000
# 75%                                           120.000000
# max                                           120.000000

# %% [markdown]
# Calculate the number of primary school students in Cardiff.

# %%
cardiff_num_students = sum(cardiff_primary_school_df['Number of Pupils 2017'])
print(cardiff_num_students)
# Out:
# 33469.0

# %% [markdown]
# Calculate the number of primary school students in Cardiff on FSM.

# %%
cardiff_fsm_students = sum((pd.to_numeric(cardiff_primary_school_df['Free school meals FSM  3 year average Primary only(%)'])/100 \
                                                  * cardiff_primary_school_df['Number of Pupils 2017']).dropna())
print(cardiff_fsm_students)
# Out:
# 7513.486999999998

# %% [markdown]
# Calculate the percentage of primary school students in Cardiff who are on FSM.

# %%
cardiff_fsm_students/cardiff_num_students *100
# Out:
# 22.44909319071379

# %% [markdown]
# From this we can see that the local schools actually have fewer primary school children on FSM.

# %% [markdown]
# The my local schools website has many other tables we can study to get a more detailed picture of the schools than the summary information we have looked at so far. The function below takes the URL for the schools page and the tableid for the table you want (which you have to get by looking at the source code for the website) and returns the data from that table in a pandas data frame.

# %%
def load_table_into_dataFrame(schoolURL,tableid):
    school_pages = requests.get(schoolURL)
    school_soup = BeautifulSoup(school_pages.content, 'html.parser')
    table = school_soup.find_all('table', id=tableid)
    if table == []:
        return []
    columns = [int(table[0].find_all('th')[i].getText().strip()) for i in range(1,len(table[0].find_all('th')))]
    rows = [table[0].find_all('td')[i].getText().strip() \
            for i in range(len(table[0].find_all('td'))) if i%(len(columns)+1)==0]
    table_entries_list = [table[0].find_all('td')[i].getText().strip()\
                      for i in range(len(table[0].find_all('td'))) if i%(len(columns)+1)!=0]
    table_entries = {}
    for i,row in enumerate(rows):
        table_entries[row]={}
        for j,column in enumerate(columns):
            table_entries[row][column] = tofloat(table_entries_list[i*len(columns)+j])
    return pd.DataFrame.from_dict(table_entries,orient='index')

# %% [markdown]
# Below are the tableids for the tables of special educational need (SEN) and English as an additional language (EAL). For information on what these statistics mean, look at the my local schools website.

# %%
sen_table_id = 'atbl239'
eal_table_id = 'atbl240'

# %% [markdown]
# We now make a dictionary linking each school to its SEN table.

# %%
sen_dict = {}
for school in primary_school_URLs.keys():
    sen_dict[school] = load_table_into_dataFrame(primary_school_URLs[school],sen_table_id)
    if not len(sen_dict[school]):
        del sen_dict[school]

# %% [markdown]
# Lets focus on the school action statistic. Here we make data frames for all primary schools in Cardiff and from this make another data frame with just the local schools.

# %%
school_action_dict = {}
for school in sen_dict.keys():
    school_action_dict[school] = sen_dict[school].loc['School - School Action']
school_action_df = pd.DataFrame.from_dict(school_action_dict,orient='index') 
local_school_action_df = school_action_df.loc[local_schools]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """

# %% [markdown]
# Looking at the summary data, it seems like the local schools are fairly typical of Cardiff schools in general when it comes to the percentage of SEN students.

# %%
local_school_action_df.describe()
# Out:
#             2011       2012       2013       2014       2015       2016  \
# count  10.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   17.950000  19.836364  17.518182  19.236364  16.936364  14.127273
# std     6.224548   9.433798   8.569460   9.669361   8.769638   4.021216
# min    11.600000   4.500000   3.400000   6.800000   5.600000   6.100000
# 25%    13.800000  13.500000  12.500000  11.000000  11.000000  11.700000
# 50%    17.000000  21.200000  15.700000  20.000000  15.900000  14.300000
# 75%    19.300000  23.400000  20.700000  23.150000  18.950000  17.400000
# max    33.100000  37.200000  35.100000  37.700000  35.900000  19.000000
#
#             2017
# count  11.000000
# mean   14.009091
# std     5.605257
# min     4.500000
# 25%     9.200000
# 50%    15.700000
# 75%    16.700000
# max    24.600000

# %%
school_action_df.describe()
# Out:
#             2011       2012       2013       2014       2015       2016  \
# count  88.000000  91.000000  95.000000  93.000000  95.000000  94.000000
# mean   17.947727  18.998901  18.497895  18.000000  16.836842  15.830851
# std     9.182191  10.106230   9.224159   8.348015   8.681235   7.548667
# min     4.600000   4.500000   3.400000   2.400000   2.000000   3.400000
# 25%    11.525000  10.600000  12.350000  11.500000  11.100000   9.925000
# 50%    16.150000  17.400000  16.300000  17.400000  14.000000  14.350000
# 75%    21.900000  24.200000  23.000000  23.500000  22.550000  19.875000
# max    46.200000  51.600000  50.400000  47.400000  41.100000  40.900000
#
#             2017
# count  94.000000
# mean   15.363830
# std     7.749185
# min     2.800000
# 25%     9.425000
# 50%    15.200000
# 75%    20.100000
# max    38.200000

# %% [markdown]
# It would be interesting to note the total number of SEN students in the area. This data is not directly available, so I multiply the number of students in each school by the percentage of SEN students to get an approximate number.
#
# Below is a histogram showing the difference between the number of SEN students at local schools and the median number of SEN students for Cardiff. Negative indicates schools with fewer SEN students than the Cardiff median. It shows a wide variation in the number of SEN students per school. St. Paul's C/W primary schools has the 3rd lowest number of SEN students of all the primary schools in Cardiff, while many other schools have a lot more.

# %%
number_local_sen_students = local_school_df['Number of Pupils 2017']*school_action_df.loc[local_schools,2017]/100
number_cardiff_sen_students = cardiff_primary_school_df['Number of Pupils 2017']*school_action_df.loc[:,2017]/100
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1020: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]

# %%
(number_local_sen_students-number_cardiff_sen_students.median()).plot(kind='barh')

# %% [markdown]
# Below is a histogram of the 10 primary schools with the most SEN students. Grangetown, one of our local schools is ranked number 7.

# %%
number_cardiff_sen_students.sort_values().dropna()[-10:].plot(kind='barh')

# %% [markdown]
# Below we can see that there is one local school (Grangetown) in the top decile for most SEN students. Five of our 12 local schools are in the top quartile for SEN.

# %%
upperQ = int(len(number_cardiff_sen_students.sort_values().dropna())*0.75)
upperD = int(len(number_cardiff_sen_students.sort_values().dropna())*0.90)

# %%
number_cardiff_sen_students.sort_values().dropna()[upperD:][local_schools]
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py:705: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# Severn Primary                        NaN
# St. Mary's R.C. Primary School        NaN
# St.Paul's C/W Primary School          NaN
# Grangetown Primary School          99.384
# St Patrick's R C School               NaN
# Ysgol Gynradd Gymraeg Hamadryad       NaN
# Ninian Park Primary School            NaN
# Kitchener Primary School              NaN
# Radnor Primary School                 NaN
# Lansdowne Primary School              NaN
# Ysgol Treganna                        NaN
# Ysgol Gymraeg Pwll Coch               NaN
# dtype: float64

# %%
number_cardiff_sen_students.sort_values().dropna()[upperQ:][local_schools]
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py:705: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# Severn Primary                     78.566
# St. Mary's R.C. Primary School        NaN
# St.Paul's C/W Primary School          NaN
# Grangetown Primary School          99.384
# St Patrick's R C School               NaN
# Ysgol Gynradd Gymraeg Hamadryad       NaN
# Ninian Park Primary School            NaN
# Kitchener Primary School           83.106
# Radnor Primary School                 NaN
# Lansdowne Primary School           76.302
# Ysgol Treganna                        NaN
# Ysgol Gymraeg Pwll Coch            90.068
# dtype: float64

# %% [markdown]
# Now we will look at the number of students in the local area who speak English as an additional language (EAL).

# %%
eal_dict = {}
for school in primary_school_URLs.keys():
    temp = load_table_into_dataFrame(primary_school_URLs[school],eal_table_id)
    try:
        eal_dict[school] = temp.loc['School']
    except (KeyError, AttributeError):
        continue

# %%
eal_df = pd.DataFrame.from_dict(eal_dict,orient='index')

# %%
eal_df.describe()
# Out:
#             2011       2012       2013       2014       2015       2016  \
# count  62.000000  65.000000  67.000000  68.000000  70.000000  69.000000
# mean   23.882258  24.807692  25.791045  26.358824  27.230000  27.642029
# std    24.479054  24.028904  24.445175  24.802655  25.622507  25.288258
# min     1.500000   1.500000   1.500000   2.100000   1.600000   2.400000
# 25%     5.775000   7.500000   7.000000   8.275000   7.575000   8.800000
# 50%    12.700000  14.600000  16.900000  17.350000  17.850000  18.300000
# 75%    37.625000  36.400000  34.850000  36.500000  40.150000  42.900000
# max    92.500000  91.000000  90.200000  90.700000  92.900000  91.300000
#
#             2017
# count  76.000000
# mean   24.205263
# std    22.767538
# min     2.200000
# 25%     6.275000
# 50%    14.700000
# 75%    34.725000
# max    87.800000

# %%
eal_df.loc[local_schools].describe()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#             2011       2012       2013       2014       2015       2016  \
# count   9.000000   9.000000   9.000000   9.000000   9.000000   9.000000
# mean   50.122222  50.188889  52.155556  54.877778  56.133333  55.966667
# std    30.388805  30.356525  28.655371  28.410068  27.949866  24.678786
# min    13.100000  13.800000  19.900000  17.700000  18.800000  23.400000
# 25%    26.100000  26.900000  27.600000  32.400000  33.700000  36.000000
# 50%    39.900000  42.800000  43.000000  45.500000  47.300000  48.000000
# 75%    73.000000  71.300000  77.100000  83.900000  84.800000  75.200000
# max    92.500000  91.000000  90.200000  90.700000  92.900000  91.300000
#
#             2017
# count   9.000000
# mean   52.722222
# std    23.870891
# min    21.200000
# 25%    35.400000
# 50%    50.100000
# 75%    73.600000
# max    87.800000

# %%
num_eal_students_local = (cardiff_primary_school_df['Number of Pupils 2017']*eal_df.loc[:,2017]/100)[local_schools]
num_eal_students_cardiff = (cardiff_primary_school_df['Number of Pupils 2017']*eal_df.loc[:,2017]/100)

# %%
num_eal_students_local
# Out:
# Severn Primary                     281.006
# St. Mary's R.C. Primary School     101.529
# St.Paul's C/W Primary School        59.565
# Grangetown Primary School          354.712
# St Patrick's R C School            105.492
# Ysgol Gynradd Gymraeg Hamadryad        NaN
# Ninian Park Primary School         449.499
# Kitchener Primary School           357.696
# Radnor Primary School               68.476
# Lansdowne Primary School           243.486
# Ysgol Treganna                         NaN
# Ysgol Gymraeg Pwll Coch                NaN
# dtype: float64

# %%
num_eal_students_local.describe()
# Out:
# count      9.000000
# mean     224.606778
# std      145.647690
# min       59.565000
# 25%      101.529000
# 50%      243.486000
# 75%      354.712000
# max      449.499000
# dtype: float64

# %%
num_eal_students_cardiff.describe()
# Out:
# count     76.000000
# mean      85.252579
# std       93.980054
# min        7.752000
# 25%       18.449500
# 50%       58.178000
# 75%      102.519750
# max      449.499000
# dtype: float64

# %%
non_local_school = [school for school in num_eal_students_cardiff.keys() if school not in local_schools]

# %%
(pd.concat([num_eal_students_cardiff, num_eal_students_cardiff[non_local_school], num_eal_students_local]\
           ,axis=1,keys=['Cardiff','Cardiff - local','Local'])).plot(kind='box',title='Number of EAL students')

# %%
pc90_eal = num_eal_students_cardiff[num_eal_students_cardiff>num_eal_students_cardiff.quantile(q=0.9)].keys()
len(pc90_eal)
# Out:
# 8

# %% [markdown]
# Of the 12 local schools, 5 are in the top 90percentile for EAL students.

# %%
sum(np.isin(local_schools,pc90_eal))
# Out:
# 5

# %% [markdown]
# Of the 8 schools in the top 90 percentile for EAL students, 5 are in the local area.

# %%
sum(np.isin(pc90_eal,local_schools,))
# Out:
# 5

# %%
local_pc90 = pc90_eal[np.isin(pc90_eal,local_schools)]
non_local_pc90 = pc90_eal[~np.isin(pc90_eal,local_schools)]

# %%
pc90_local_nonlocal = pd.concat([num_eal_students_cardiff[non_local_pc90],num_eal_students_cardiff[local_pc90]]\
          ,axis=1,keys=['Non-local','Local'])

# %%
pc90_eal_df = num_eal_students_cardiff[pc90_eal]

# %%
order = pc90_eal_df.sort_values().keys()

# %%
pc90_local_nonlocal.set_index(pc90_eal).loc[order].plot(kind='bar')

# %%
order = num_eal_students_cardiff.dropna().sort_values().keys()

# %%
local_nonlocal_eal = pd.concat([num_eal_students_cardiff[non_local_school],num_eal_students_cardiff[local_schools]],\
                                                                                    axis=1,keys=['non-local','local'])
local_nonlocal_eal.set_index(num_eal_students_cardiff.keys()).loc[order].plot(kind='bar',figsize=(15,7))

# %%
local_nonlocal_eal.sum().plot(kind='pie',figsize=(7,7),title='Number of EAL students')

# %%
local_nonlocal_students = pd.concat([cardiff_primary_school_df['Number of Pupils 2017'][non_local_school],\
           cardiff_primary_school_df['Number of Pupils 2017'][local_schools]],\
          keys=['non-local','local'], axis=1).sum()
local_nonlocal_students.plot(kind='pie',figsize=(7,7),title='Number of students')

# %%
local_nonlocal_eal.sum()/local_nonlocal_students
# Out:
# non-local    0.154691
# local        0.434536
# dtype: float64
