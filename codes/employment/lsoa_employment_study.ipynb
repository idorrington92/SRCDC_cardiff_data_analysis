# %% [markdown]
# This script looks at employment data from the 2011 census. The data is organised by output area, OA. In this script, the OAs are amalgamated into lower super output areas, LSOAs, which are larger areas of appoximately 1500 people. The lsoa_to_oa_dict is a dictionary that takes in the OA code for any OA and returns the LSOA code of the LSOA that OA is in.

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# This dictionaries map OAs to their LSOAs and vice versa.

# %%
oa_to_lsoa_dict = np.load('../utilities/oa_to_lsoa_dict.npy').item(0)
lsoa_to_oa_dict = np.load('../utilities/lsoa_to_oa_dict.npy').item(0)

# %% [markdown]
# These are the LSOA codes we are interested in (the areas where SRCDC operates). Note that south Grangetown and North Riverside are nearby areas, but not areas that SRCDC operates in.

# %%
grangetown_codes = ['W01001759','W01001760','W01001761','W01001762','W01001764','W01001765',\
                    'W01001766','W01001767','W01001768','W01001946']
canton_codes = ['W01001709', 'W01001710', 'W01001711', 'W01001712', 'W01001713', 'W01001714',\
                'W01001715', 'W01001716', 'W01001717'] 
riverside_codes = ['W01001855', 'W01001856', 'W01001857', 'W01001862']
lsoa_codes = np.concatenate([grangetown_codes, canton_codes, riverside_codes])


#south_grangetown=['W01001945','W01001947']
#north_riverside = ['W01001858', 'W01001859', 'W01001860','W01001861']

# %% [markdown]
# This is a list of the OAs in the LSOAs we are interested in.

# %%
local_oa_codes = [oa_code for lsoa_code in lsoa_codes for oa_code in lsoa_to_oa_dict[lsoa_code]]

# %% [markdown]
# Here we load the csv file containing the census data, edit the column headers to make them more readable, and then sort the data by OA.

# %%
full_data = pd.read_csv('census_employment_data.csv')
new_keys = []
for key in full_data.keys():
    if 'Economic Activity' in key:
        new_keys.append(''.join(key.split(':')[1:-1]).split(';')[0].strip())
    else:
        new_keys.append(key.strip())
full_data.columns = new_keys
full_data = full_data.set_index('geography')

# %% [markdown]
# The data is organised by OA, but we want to study LSOAs, so we add a column to the dataframe that lists the LSOA of the OA.

# %%
full_data['LSOA'] = list(map(lambda oa : oa_to_lsoa_dict[oa], full_data['geography code']))

# %% [markdown]
# This snippet makes a new dataframe with the employment statistics of the LSOAs. These are calculated by summing the OA data for every OA in each LSOA.

# %%
lsoas = dict.fromkeys(np.unique(full_data['LSOA']))
for lsoa in lsoas.keys():
    lsoas[lsoa] = full_data[full_data['LSOA']==lsoa].drop('date',axis=1).sum(numeric_only=True)

lsoa_data = pd.DataFrame.from_dict(lsoas,orient='index')

# %% [markdown]
# Here we make smaller dataframes containing just the local LSOAs, or just the non-local LSOAs. We then look at the summary information for each of these.

# %%
local_lsoa_data = lsoa_data.loc[lsoa_codes]
nonlocal_lsoa_codes = [lsoa for lsoa in lsoa_data.index.values if lsoa not in lsoa_codes]
nonlocal_lsoa_data = lsoa_data.loc[nonlocal_lsoa_codes]

# %%
local_lsoa_data.describe()
# Out:
#        All usual residents aged 16 to 74  Economically active  \
# count                          23.000000            23.000000
# mean                         1219.043478           837.086957
# std                           137.928334           107.182051
# min                           930.000000           609.000000
# 25%                          1138.500000           771.500000
# 50%                          1224.000000           859.000000
# 75%                          1309.000000           903.000000
# max                          1475.000000          1040.000000
#
#        Economically active In employment  \
# count                          23.000000
# mean                          720.913043
# std                           116.990253
# min                           531.000000
# 25%                           643.000000
# 50%                           677.000000
# 75%                           819.500000
# max                           930.000000
#
#        Economically active Employee Part-time  \
# count                               23.000000
# mean                               165.043478
# std                                 24.251482
# min                                123.000000
# 25%                                142.500000
# 50%                                165.000000
# 75%                                187.000000
# max                                206.000000
#
#        Economically active Employee Full-time  \
# count                               23.000000
# mean                               454.347826
# std                                 97.222149
# min                                292.000000
# 25%                                395.500000
# 50%                                413.000000
# 75%                                533.500000
# max                                637.000000
#
#        Economically active Self-employed  Economically active Unemployed  \
# count                          23.000000                       23.000000
# mean                          101.521739                       66.130435
# std                            26.241656                       24.698738
# min                            58.000000                       23.000000
# 25%                            83.000000                       43.000000
# 50%                           101.000000                       69.000000
# 75%                           111.000000                       82.500000
# max                           156.000000                      117.000000
#
#        Economically active Full-time student  Economically Inactive  \
# count                              23.000000              23.000000
# mean                               50.043478             381.956522
# std                                36.326147             104.437227
# min                                16.000000             216.000000
# 25%                                31.000000             320.000000
# 50%                                40.000000             358.000000
# 75%                                54.000000             451.500000
# max                               193.000000             600.000000
#
#        Economically inactive Retired  \
# count                      23.000000
# mean                      106.086957
# std                        24.927008
# min                        67.000000
# 25%                        87.000000
# 50%                       100.000000
# 75%                       126.500000
# max                       151.000000
#
#        Economically inactive Student (including full-time students)  \
# count                                          23.000000
# mean                                           78.173913
# std                                            49.280876
# min                                            34.000000
# 25%                                            52.000000
# 50%                                            65.000000
# 75%                                            82.000000
# max                                           252.000000
#
#        Economically inactive Looking after home or family  \
# count                                          23.000000
# mean                                           70.608696
# std                                            30.961470
# min                                            23.000000
# 25%                                            46.000000
# 50%                                            63.000000
# 75%                                            93.500000
# max                                           122.000000
#
#        Economically inactive Long-term sick or disabled  \
# count                                         23.000000
# mean                                          83.652174
# std                                           33.614944
# min                                           26.000000
# 25%                                           67.000000
# 50%                                           80.000000
# 75%                                           94.500000
# max                                          159.000000
#
#        Economically inactive Other  Unemployed Age 16 to 24  \
# count                    23.000000                23.000000
# mean                     43.434783                18.695652
# std                      23.113998                 9.319748
# min                       7.000000                 3.000000
# 25%                      27.000000                10.000000
# 50%                      37.000000                20.000000
# 75%                      60.000000                25.000000
# max                      94.000000                41.000000
#
#        Unemployed Age 50 to 74  Unemployed Never worked  Long-term unemployed
# count                23.000000                23.000000             23.000000
# mean                 10.739130                14.043478             24.304348
# std                   4.423259                 8.751510              9.734824
# min                   3.000000                 2.000000              7.000000
# 25%                   7.000000                 5.500000             17.500000
# 50%                  11.000000                17.000000             23.000000
# 75%                  14.500000                19.500000             30.000000
# max                  18.000000                31.000000             48.000000

# %%
nonlocal_lsoa_data.describe()
# Out:
#        All usual residents aged 16 to 74  Economically active  \
# count                        1886.000000          1886.000000
# mean                         1175.571580           772.790032
# std                           270.456072           189.552866
# min                           682.000000           349.000000
# 25%                          1007.000000           644.000000
# 50%                          1118.000000           745.000000
# 75%                          1292.000000           871.000000
# max                          3908.000000          1815.000000
#
#        Economically active In employment  \
# count                        1886.000000
# mean                          683.890774
# std                           182.597817
# min                           173.000000
# 25%                           559.000000
# 50%                           663.000000
# 75%                           779.000000
# max                          1656.000000
#
#        Economically active Employee Part-time  \
# count                             1886.000000
# mean                               163.958643
# std                                 40.683124
# min                                 34.000000
# 25%                                137.000000
# 50%                                160.000000
# 75%                                187.000000
# max                                337.000000
#
#        Economically active Employee Full-time  \
# count                             1886.000000
# mean                               418.291622
# std                                126.807918
# min                                106.000000
# 25%                                335.000000
# 50%                                401.000000
# 75%                                480.000000
# max                               1286.000000
#
#        Economically active Self-employed  Economically active Unemployed  \
# count                        1886.000000                     1886.000000
# mean                          101.640509                       50.460233
# std                            66.050572                       25.065416
# min                            14.000000                        7.000000
# 25%                            60.000000                       31.000000
# 50%                            82.000000                       46.000000
# 75%                           121.000000                       64.000000
# max                           496.000000                      165.000000
#
#        Economically active Full-time student  Economically Inactive  \
# count                            1886.000000            1886.000000
# mean                               38.439024             402.781548
# std                                57.562276             143.630025
# min                                 3.000000             122.000000
# 25%                                22.000000             324.000000
# 50%                                29.000000             384.500000
# 75%                                37.000000             452.000000
# max                               943.000000            2551.000000
#
#        Economically inactive Retired  \
# count                    1886.000000
# mean                      190.382291
# std                        67.467534
# min                        13.000000
# 25%                       147.000000
# 50%                       184.000000
# 75%                       229.750000
# max                       524.000000
#
#        Economically inactive Student (including full-time students)  \
# count                                        1886.000000
# mean                                           70.032874
# std                                           128.654300
# min                                            12.000000
# 25%                                            40.000000
# 50%                                            49.000000
# 75%                                            61.000000
# max                                          2406.000000
#
#        Economically inactive Looking after home or family  \
# count                                        1886.000000
# mean                                           44.948038
# std                                            20.356594
# min                                             9.000000
# 25%                                            31.000000
# 50%                                            41.000000
# 75%                                            55.000000
# max                                           150.000000
#
#        Economically inactive Long-term sick or disabled  \
# count                                       1886.000000
# mean                                          73.613998
# std                                           41.480474
# min                                            4.000000
# 25%                                           41.000000
# 50%                                           68.000000
# 75%                                           99.000000
# max                                          249.000000
#
#        Economically inactive Other  Unemployed Age 16 to 24  \
# count                  1886.000000              1886.000000
# mean                     23.804348                16.088017
# std                      26.644738                 9.678804
# min                       1.000000                 0.000000
# 25%                      15.000000                 9.000000
# 50%                      20.000000                14.000000
# 75%                      29.000000                22.000000
# max                     954.000000                72.000000
#
#        Unemployed Age 50 to 74  Unemployed Never worked  Long-term unemployed
# count              1886.000000              1886.000000           1886.000000
# mean                  8.787381                 7.756098             20.079003
# std                   4.338327                 6.415325             12.000116
# min                   0.000000                 0.000000              1.000000
# 25%                   6.000000                 3.000000             11.000000
# 50%                   8.000000                 6.000000             18.000000
# 75%                  11.000000                10.000000             26.000000
# max                  30.000000                42.000000             75.000000

# %% [markdown]
# For the LSOA data, we add a new column which contains a 1 is the LSOA is local, and a 0 otherwise. This allows us to quickly compare local and non-local LSOAs.

# %%
lsoa_data['local'] = list(map(lambda lsoa : int(np.isin(lsoa,lsoa_codes)), lsoa_data.index.values))

# %% [markdown]
# This is a little function that makes useful plots. In particular, it can make a box plot of a given statistic for local and non-local LSOAs, a scatter plot of any 2 given statistics, or a bar chart or the top 1 percentile for any given statistic. For the bar chart, the function also returns the LSOA code for any LSOA in the top n percentiles for that statistic, where n is chosen by the user.

# %%
def plot_two_data_sets(stat,data,stat2=None,kind='bar',figsize=(15,7),percentile=10.0): 
    if kind == 'bar':
        percentile/=100.
        order = data[stat].dropna().sort_values().keys()
        lnl_data = pd.concat([data[data['local']==True][stat],data[data['local']==False][stat]],\
                                                             axis=1,keys=['local','non-local'])
        if percentile>0:
            lnl_data.set_index(lnl_data.index.values).loc[order[-int(len(data)*percentile):]].plot(\
                                                                kind=kind,title=stat,figsize=figsize)
            return [code for code in order[-int(len(data)*percentile):] if data['local'][code]==True ]
        else:
            lnl_data.set_index(lnl_data.index.values).loc[order[:-int(len(data)*percentile)]].plot(\
                                                                kind=kind,title=stat,figsize=figsize)
            return [code for code in order[:-int(len(data)*percentile)] if data['local'][code]==True ]

    elif kind == 'scatter':
        data.plot.scatter(x=stat, y=stat2,c='local',colormap='viridis',figsize=figsize)
    else:
        lnl_data = pd.concat([data[data['local']==True][stat],data[data['local']==False][stat]],\
                             axis=1,keys=['local','non-local'])
        lnl_data.plot(kind=kind,title=stat,figsize=figsize)

# %% [markdown]
# Here we plot the number of people looking after their home or family against the number of people with a disability. There is clearly a correlation, which is not surprising, but it looks like the local LSOAs tend to have more people looking after the home than expected given the number of sick and disabled people in the local area. As the local area is younger than the average for Wales, this probably indicates that there are more stay-home parents.

# %%
stat = 'Economically inactive Long-term sick or disabled'
stat2 = 'Economically inactive Looking after home or family'
data = lsoa_data
plot_two_data_sets(stat=stat,stat2=stat2,data=data,kind='scatter',figsize=(9,7))

# %% [markdown]
# Here we plot all the economic statistics as box plots and bar charts. We first look at the total numbers. We then look at the numbers divided by the number of people in the LSOA to get a rate. Any LSOA in the local area that is in the top 10 percentile for Wales is saved in the extreme_values dictionary.

# %%
extreme_lsoas = {}
data=lsoa_data
for stat in lsoa_data.keys():
    plot_two_data_sets(stat=stat,data=data,kind='box',figsize=(7,7))
    extreme_lsoas[stat] = plot_two_data_sets(stat=stat,data=data,kind='bar',percentile=10.0)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# Here we count the number of local LSOAs in the top 10 percentiles for Wales for each statistic.

# %%
extreme_count = {key : len(extreme_lsoas[key]) for key in extreme_lsoas.keys()}
extreme_count
# Out:
# {'All usual residents aged 16 to 74': 0,
#  'Economically Inactive': 3,
#  'Economically active': 1,
#  'Economically active Employee Full-time': 5,
#  'Economically active Employee Part-time': 0,
#  'Economically active Full-time student': 9,
#  'Economically active In employment': 2,
#  'Economically active Self-employed': 0,
#  'Economically active Unemployed': 6,
#  'Economically inactive Long-term sick or disabled': 3,
#  'Economically inactive Looking after home or family': 10,
#  'Economically inactive Other': 11,
#  'Economically inactive Retired': 0,
#  'Economically inactive Student (including full-time students)': 7,
#  'Long-term unemployed': 2,
#  'Unemployed Age 16 to 24': 1,
#  'Unemployed Age 50 to 74': 6,
#  'Unemployed Never worked': 12,
#  'local': 23}

# %%
extreme_lsoas
# Out:
# {'All usual residents aged 16 to 74': [],
#  'Economically Inactive': ['W01001857', 'W01001764', 'W01001856'],
#  'Economically active': ['W01001709'],
#  'Economically active Employee Full-time': ['W01001712',
#   'W01001717',
#   'W01001709',
#   'W01001713',
#   'W01001715'],
#  'Economically active Employee Part-time': [],
#  'Economically active Full-time student': ['W01001709',
#   'W01001760',
#   'W01001768',
#   'W01001766',
#   'W01001762',
#   'W01001855',
#   'W01001856',
#   'W01001862',
#   'W01001764'],
#  'Economically active In employment': ['W01001709', 'W01001713'],
#  'Economically active Self-employed': [],
#  'Economically active Unemployed': ['W01001766',
#   'W01001855',
#   'W01001856',
#   'W01001857',
#   'W01001862',
#   'W01001762'],
#  'Economically inactive Long-term sick or disabled': ['W01001762',
#   'W01001856',
#   'W01001857'],
#  'Economically inactive Looking after home or family': ['W01001766',
#   'W01001762',
#   'W01001767',
#   'W01001862',
#   'W01001857',
#   'W01001761',
#   'W01001764',
#   'W01001856',
#   'W01001768',
#   'W01001855'],
#  'Economically inactive Other': ['W01001946',
#   'W01001764',
#   'W01001766',
#   'W01001762',
#   'W01001765',
#   'W01001768',
#   'W01001857',
#   'W01001862',
#   'W01001855',
#   'W01001761',
#   'W01001856'],
#  'Economically inactive Retired': [],
#  'Economically inactive Student (including full-time students)': ['W01001761',
#   'W01001857',
#   'W01001855',
#   'W01001768',
#   'W01001862',
#   'W01001856',
#   'W01001764'],
#  'Long-term unemployed': ['W01001857', 'W01001762'],
#  'Unemployed Age 16 to 24': ['W01001762'],
#  'Unemployed Age 50 to 74': ['W01001857',
#   'W01001760',
#   'W01001761',
#   'W01001762',
#   'W01001862',
#   'W01001855'],
#  'Unemployed Never worked': ['W01001761',
#   'W01001764',
#   'W01001767',
#   'W01001855',
#   'W01001768',
#   'W01001765',
#   'W01001760',
#   'W01001856',
#   'W01001766',
#   'W01001857',
#   'W01001862',
#   'W01001762'],
#  'local': ['W01001759',
#   'W01001760',
#   'W01001762',
#   'W01001766',
#   'W01001765',
#   'W01001768',
#   'W01001767',
#   'W01001946',
#   'W01001764',
#   'W01001862',
#   'W01001716',
#   'W01001710',
#   'W01001711',
#   'W01001712',
#   'W01001713',
#   'W01001714',
#   'W01001715',
#   'W01001717',
#   'W01001855',
#   'W01001856',
#   'W01001857',
#   'W01001709',
#   'W01001761']}

# %%
extreme_lsoas = {}
data=lsoa_data
keys = [key for key in local_lsoa_data.keys() if key!='All usual residents aged 16 to 74']
for stat in keys:
    data[stat]/=lsoa_data['All usual residents aged 16 to 74']
    plot_two_data_sets(stat=stat,data=data,kind='box',figsize=(7,7))
    extreme_lsoas[stat] = plot_two_data_sets(stat=stat,data=data,kind='bar',percentile=10.0)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# Here we count the number of local LSOAs in the top 10 percentiles for Wales for each statistic.

# %%
extreme_count = {key : len(extreme_lsoas[key]) for key in extreme_lsoas.keys()}
extreme_count
# Out:
# {'Economically Inactive': 0,
#  'Economically active': 7,
#  'Economically active Employee Full-time': 6,
#  'Economically active Employee Part-time': 2,
#  'Economically active Full-time student': 9,
#  'Economically active In employment': 6,
#  'Economically active Self-employed': 0,
#  'Economically active Unemployed': 4,
#  'Economically inactive Long-term sick or disabled': 2,
#  'Economically inactive Looking after home or family': 11,
#  'Economically inactive Other': 10,
#  'Economically inactive Retired': 0,
#  'Economically inactive Student (including full-time students)': 8,
#  'Long-term unemployed': 1,
#  'Unemployed Age 16 to 24': 2,
#  'Unemployed Age 50 to 74': 4,
#  'Unemployed Never worked': 8}

# %% [markdown]
# Below is a count of the number of times each local LSOAs that appear in the top 100 LSOAs for one of the statistics. I removed the number of students as this does not indicate whether an area is deprived or not. All of the remaining statistics are ones that suggest a more deprived area.

# %%
interesting_stat = {}
for stat in extreme_lsoas.keys():
    if extreme_lsoas[stat] != []:
        interesting_stat[stat] = extreme_lsoas[stat]
del interesting_stat['Economically active Full-time student']
del interesting_stat['Economically inactive Student (including full-time students)']

lsoa_count = {}
for stat in interesting_stat.keys():
    for lsoa in interesting_stat[stat]:
        if lsoa in lsoa_count.keys():
            lsoa_count[lsoa]+=1
        else:
            lsoa_count[lsoa] = 1
lsoa_count
# Out:
# {'W01001709': 1,
#  'W01001711': 1,
#  'W01001712': 3,
#  'W01001713': 3,
#  'W01001714': 3,
#  'W01001715': 3,
#  'W01001716': 2,
#  'W01001717': 1,
#  'W01001759': 3,
#  'W01001760': 2,
#  'W01001761': 3,
#  'W01001762': 8,
#  'W01001764': 1,
#  'W01001765': 4,
#  'W01001766': 4,
#  'W01001767': 2,
#  'W01001768': 3,
#  'W01001855': 3,
#  'W01001856': 2,
#  'W01001857': 5,
#  'W01001862': 5,
#  'W01001946': 1}

# %% [markdown]
# The worst local areas according to these employment measures are GRA4, and then RIV2,3, and 8. This matches what we would expect from the WIMD data.

# %%
extreme_lsoas
# Out:
# {'Economically Inactive': [],
#  'Economically active': ['W01001714',
#   'W01001709',
#   'W01001759',
#   'W01001713',
#   'W01001716',
#   'W01001715',
#   'W01001712'],
#  'Economically active Employee Full-time': ['W01001714',
#   'W01001759',
#   'W01001713',
#   'W01001717',
#   'W01001712',
#   'W01001715'],
#  'Economically active Employee Part-time': ['W01001760', 'W01001711'],
#  'Economically active Full-time student': ['W01001760',
#   'W01001762',
#   'W01001716',
#   'W01001855',
#   'W01001766',
#   'W01001768',
#   'W01001856',
#   'W01001862',
#   'W01001764'],
#  'Economically active In employment': ['W01001759',
#   'W01001716',
#   'W01001714',
#   'W01001713',
#   'W01001715',
#   'W01001712'],
#  'Economically active Self-employed': [],
#  'Economically active Unemployed': ['W01001857',
#   'W01001766',
#   'W01001862',
#   'W01001762'],
#  'Economically inactive Long-term sick or disabled': ['W01001762',
#   'W01001857'],
#  'Economically inactive Looking after home or family': ['W01001764',
#   'W01001862',
#   'W01001857',
#   'W01001766',
#   'W01001762',
#   'W01001765',
#   'W01001761',
#   'W01001767',
#   'W01001856',
#   'W01001855',
#   'W01001768'],
#  'Economically inactive Other': ['W01001766',
#   'W01001946',
#   'W01001762',
#   'W01001857',
#   'W01001862',
#   'W01001768',
#   'W01001855',
#   'W01001765',
#   'W01001856',
#   'W01001761'],
#  'Economically inactive Retired': [],
#  'Economically inactive Student (including full-time students)': ['W01001761',
#   'W01001857',
#   'W01001855',
#   'W01001765',
#   'W01001768',
#   'W01001862',
#   'W01001856',
#   'W01001764'],
#  'Long-term unemployed': ['W01001762'],
#  'Unemployed Age 16 to 24': ['W01001765', 'W01001762'],
#  'Unemployed Age 50 to 74': ['W01001862',
#   'W01001761',
#   'W01001762',
#   'W01001855'],
#  'Unemployed Never worked': ['W01001767',
#   'W01001760',
#   'W01001768',
#   'W01001766',
#   'W01001857',
#   'W01001765',
#   'W01001862',
#   'W01001762']}
